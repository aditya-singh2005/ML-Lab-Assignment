# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from data import load_iris_data

# %%
X, y = load_iris_data()
df = pd.DataFrame(X, columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
df['species'] = y
df.head()
# Out:
# 2025-10-21 16:38:06,382 - INFO - Loading Iris dataset...
# 2025-10-21 16:38:09,561 - INFO - Preprocessing Iris labels...
# 2025-10-21 16:38:09,563 - INFO - Iris dataset loaded: 150 samples, 4 features, 3 classes
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.set(style="ticks")
pairplot = sns.pairplot(df, hue='species', diag_kind='hist')
plt.suptitle("Iris Dataset - Feature Relationships", y=1.02)
plt.show()

# %%
save_path = "iris_eda_plot.png"
pairplot.savefig(save_path)
print(f"EDA plot saved at {save_path}")
# Out:
# EDA plot saved at iris_eda_plot.png
